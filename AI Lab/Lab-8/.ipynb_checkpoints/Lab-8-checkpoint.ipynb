# %% [markdown]
# # Question 1

# %%
def knapSack(capacity, volume, value, itemSize):
 
    if itemSize == 0 or capacity == 0:
        return 0
 
    if (volume[itemSize-1] > capacity):
        return knapSack(capacity, volume, value, itemSize-1)
 
    else:
        return max(
            value[itemSize-1] + knapSack(capacity-volume[itemSize-1], volume, value, itemSize-1),
            knapSack(capacity, volume, value, itemSize-1))
 
 
 
volume = [6, 7, 8]
value = [10, 20, 30]
capacity = 50
itemSize = len(value)
print (knapSack(capacity, volume, value, itemSize))
# Out:
# 60

# %% [markdown]
# # Question 2

# %%
import random
  
POPULATION_SIZE = 100
  
# Valid genes
GENES = 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890,.-;:_!&quot;#%&amp;/()=?@${[]} '
  
# Target string to be generated
TARGET = "Never give up!!!"
  
class Individual(object):
    def __init__(self, chromosome):
        self.chromosome = chromosome 
        self.fitness = self.cal_fitness()
  
    @classmethod
    def mutated_genes(self):
        global GENES
        gene = random.choice(GENES)
        return gene
  
    @classmethod
    def create_gnome(self):
        global TARGET
        gnome_len = len(TARGET)
        return [self.mutated_genes() for _ in range(gnome_len)]
  
    def mate(self, par2):
  
        # chromosome for offspring
        child_chromosome = []
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):    
  
            # random probability  
            prob = random.random()
  
            # if prob is less than 0.45, insert gene
            # from parent 1 
            if prob < 0.45:
                child_chromosome.append(gp1)
  
            # if prob is between 0.45 and 0.90, insert
            # gene from parent 2
            elif prob < 0.90:
                child_chromosome.append(gp2)
  
            # otherwise insert random gene(mutate), 
            # for maintaining diversity
            else:
                child_chromosome.append(self.mutated_genes())
  
        # create new Individual(offspring) using 
        # generated chromosome for offspring
        return Individual(child_chromosome)
  
    def cal_fitness(self):
        global TARGET
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET):
            if gs != gt: fitness+= 1
        return fitness
  


global POPULATION_SIZE
  
#current generation
generation = 1
  
found = False
population = []
  
# create initial population
for _ in range(POPULATION_SIZE):
            gnome = Individual.create_gnome()
            population.append(Individual(gnome))
  
while not found:
    population = sorted(population, key = lambda x:x.fitness)
  
    if population[0].fitness <= 0:
        found = True
        break
  
    new_generation = []
  
    s = int((10*POPULATION_SIZE)/100)
    new_generation.extend(population[:s])
  
    s = int((90*POPULATION_SIZE)/100)
    for _ in range(s):
        parent1 = random.choice(population[:50])
        parent2 = random.choice(population[:50])
        child = parent1.mate(parent2)
        new_generation.append(child)
  
    population = new_generation
  
    print("Attempt: {}\tOutput: {}\tFitness: {}".\
            format(generation,
            "".join(population[0].chromosome),
            population[0].fitness))
  
    generation += 1
  
      
print("Attempt: {}\tOutput: {}\tFitness: {}".\
        format(generation,
        "".join(population[0].chromosome),
        population[0].fitness))
# Out:
# Attempt: 1	Output: mWCoetS_]H9;pTqA	Fitness: 15
# Attempt: 2	Output: anRLPsO&vy)opvjm	Fitness: 14
# Attempt: 3	Output:  qQL))uivy_wd!:_	Fitness: 13
# Attempt: 4	Output:  qQLr)uivy_u%pAx	Fitness: 12
# Attempt: 5	Output:  qQLr)uivy_u%pAx	Fitness: 12
# Attempt: 6	Output:  qQLr)uivy_u%pAx	Fitness: 12
# Attempt: 7	Output: Wea;emgiv;(.p!C_	Fitness: 10
# Attempt: 8	Output: WeP1r givX(.p!;_	Fitness: 8
# Attempt: 9	Output: WeP1r givX(.p!;_	Fitness: 8
# Attempt: 10	Output: WeP1r givX(.p!;_	Fitness: 8
# Attempt: 11	Output: $evertgiv6u.p!;N	Fitness: 7
# Attempt: 12	Output: $evertgiv6u.p!;N	Fitness: 7
# Attempt: 13	Output: $evertgiv6u.p!;N	Fitness: 7
# Attempt: 14	Output: $evertgiv6u.p!;N	Fitness: 7
# Attempt: 15	Output: Fever givX9.p!C%	Fitness: 6
# Attempt: 16	Output: Fever givX9.p!C%	Fitness: 6
# Attempt: 17	Output: Fever givX9.p!C%	Fitness: 6
# Attempt: 18	Output: aever givFr6p!C!	Fitness: 5
# Attempt: 19	Output: aever givFr6p!C!	Fitness: 5
# Attempt: 20	Output: aever givFr6p!C!	Fitness: 5
# ...
