# %% [markdown]
# # Assignment 1 IR | Boolean Model

# %% [markdown]
# ## 1. Libraries Initialization

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/maxplanko89/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
import sys
import string
from nltk.stem import WordNetLemmatizer
import tkinter as tk

# %%
def readStopWords():
    f = open("stopwords.txt", "r")
    stopWords = f.read().split()
  
    # making a Frozen Set as we want to use the "Hashing" part of it when we are processing files to ignore stopWords
    stepWordsLemm = set()
    # We are stemming Stop words too to be able to remove all stems of a stopWord 
    # i.e if have is a stopword we want to ignore have, having, haven't and so on all stems of have 
    
    for stopword in stopWords:
        stepWordsLemm.add(lemmatizer.lemmatize(stopword))
    stepWordsLemm = frozenset(stepWordsLemm)
    f.close()
    return stepWordsLemm

# %% [markdown]
# ## 3. Finding Words from Stories

# %%
def readFile(file):
#     f = open(f"./ShortStories/{file}.txt", encoding="utf8")
    f=open('./ShortStories/{}.txt'.format(file), encoding='utf-8')
    
    #   Read and Lower Case 
    data = f.read().lower()    
        
    #   Removing Punctuations
    data = data.translate(str.maketrans('','',string.punctuation))

    # We have identified all unique characters and numbers and removed all others but alphabets       
    # '9', '0', '—', 'i', 'u', 'q', '2', 'e', 'ª', 'z', 'y', '”', '8', 'd', 'v', 'o', 'm', 'f', 'b', '¨', '7', '1', 'a', '’', 'l', 'w', '§', 'j', '“', 'x', 'g', '©', 'p', '6', '3', 'r', 'c', 't', 'ã', '5', '´', '¯', '‘', 'h', '4', 's', 'k', 'n
    data = data.translate(str.maketrans('','','1234567890©§“”‘’"´¨¯—ªã'))

    # Word to word checking of file and adding to Dictionary
    
    
    for i, word in enumerate(data.split()):
        word = lemmatizer.lemmatize(word)

        if word not in stopWords and word not in dictionary.keys():
#             print(word)
            dictionary[word] = [len(dictionary),0]

    f.close()
    return

dictionary = {}
lemmatizer = WordNetLemmatizer()
stopWords = readStopWords()
# Run for Each File
for x in range(1,51):
    readFile(x)
    
print("Dictionary Length: ", len(dictionary))

f = open("dictionary.txt", "w")

with open('dictionary.txt', 'w') as the_file:

    f.write('{')

    for word in dictionary:
        f.write("'{}' : {},".format(word, dictionary[word]))
    f.write('}')

    f.close()
# Out:
# Dictionary Length:  8730

# %% [markdown]
# ## 4. Writing Index

# %%
def readFile(file):
#     f = open(f"./ShortStories/{file}.txt", encoding="utf8")
    f=open('./ShortStories/{}.txt'.format(file), encoding='utf-8')
    
    #   Read and Lower Case 
    data = f.read().lower()    
        
    #   Removing Punctuations
    data = data.translate(str.maketrans('','',string.punctuation))

    # We have identified all unique characters and numbers and removed all others but alphabets       
    # '9', '0', '—', 'i', 'u', 'q', '2', 'e', 'ª', 'z', 'y', '”', '8', 'd', 'v', 'o', 'm', 'f', 'b', '¨', '7', '1', 'a', '’', 'l', 'w', '§', 'j', '“', 'x', 'g', '©', 'p', '6', '3', 'r', 'c', 't', 'ã', '5', '´', '¯', '‘', 'h', '4', 's', 'k', 'n
    data = data.translate(str.maketrans('','','1234567890©§“”‘’"´¨¯—ªã'))

    # Word to word checking of file and adding to Dictionary
    
    
#     for i, word in enumerate(data.split()):
#         word = lemmatizer.lemmatize(word)

#         if word not in stopWords and word not in dictionary.keys():
#             dictionary[word] = [len(dictionary),0]

    for i, word in enumerate(data.split()):
        word = lemmatizer.lemmatize(word)
        if word not in stopWords:
            if word in index[x].keys():
                index[x][word] = index[x][word] + 1
            else:
                index[x][word] = 1
    f.close()
    return


index = { j: {} for j in range(1,51) }

lemmatizer = WordNetLemmatizer()
stopWords = readStopWords()
# Run for Each File
for x in range(1,51):
    readFile(x)
    
print("Index: ", index)

f = open("index.txt", "w")

with open('index.txt', 'w') as the_file:

    f.write('{')

    for doc in index:
        f.write("{} : {},".format(doc, index[doc]))
    f.write('}')

    f.close()
# Out:
# Index:  {1: {'horsestealers': 2, 'hospital': 14, 'assistant': 7, 'called': 3, 'yergunov': 50, 'an': 9, 'emptyheaded': 1, 'fellow': 13, 'known': 1, 'throughout': 1, 'district': 1, 'great': 5, 'braggart': 1, 'drunkard': 3, 'wa': 108, 'returning': 1, 'one': 42, 'evening': 3, 'christmas': 1, 'week': 1, 'from': 31, 'hamlet': 1, 'ryepino': 5, 'where': 15, 'he': 138, 'been': 23, 'make': 5, 'some': 11, 'purchase': 3, 'that': 48, 'might': 6, 'get': 12, 'home': 5, 'good': 3, 'time': 12, 'not': 53, 'late': 2, 'doctor': 5, 'lent': 1, 'him': 43, 'very': 8, 'best': 2, 'horse': 36, 'first': 6, 'it': 93, 'still': 7, 'day': 6, 'but': 38, 'eight': 1, 'oclock': 1, 'violent': 1, 'snow': 9, 'storm': 2, 'came': 11, 'when': 15, 'only': 12, 'about': 18, 'four': 2, 'mile': 3, 'completely': 1, 'lost': 3, 'way': 8, 'did': 17, 'know': 5, 'how': 8, 'drive': 3, 'road': 4, 'drove': 9, 'random': 1, 'hoping': 1, 'would': 22, 'find': 4, 'itself': 1, 'two': 5, 'hour': 2, 'passed': 6, 'exhausted': 5, 'himself': 7, 'chilled': 2, 'already': 3, 'began': 12, 'fancy': 1, 'going': 9, 'back': 10, 'towards': 3, 'last': 6, 'above': 2, 'uproar': 2, 'heard': 5, 'faraway': 1, 'barking': 1, 'dog': 9, 'murky': 1, 'red': 11, 'blur': 2, 'into': 35, 'sight': 2, 'ahead': 1, 'little': 16, 'by': 15, 'outline': 1, 'high': 3, 'gate': 5, 'could': 12, 'discerned': 1, 'then': 28, 'long': 7, 'fence': 3, 'which': 8, 'there': 42, 'were': 28, 'nail': 1, 'with': 80, 'their': 13, 'point': 1, 'uppermost': 1, 'beyond': 1, 'stood': 6, 'slanting': 1, 'crane': 1, 'well': 8, 'wind': 7, 'away': 11, 'mist': 1, 'before': 6, 'eye': 12, 'sprang': 1, 'small': 3, 'squat': 1, 'house': 9, 'steep': 2, 'thatched': 1, 'roof': 1, 'three': 6, 'window': 2, 'covered': 4, 'inside': 1, 'something': 5, 'lighted': 3, 'what': 25, 'sort': 5, 'place': 3, 'remembered': 3, 'right': 3, 'half': 5, 'or': 16, 'andrey': 4, 'tchirikovs': 2, 'tavern': 5, 'too': 11, 'this': 8, 'tchirikov': 1, 'who': 18, 'lately': 1, 'killed': 1, 'sledgedrivers': 1, 'left': 5, 'wife': 3, 'daughter': 2, 'lyubka': 36, 'come': 7, 'year': 3, 'patient': 1, 'inn': 5, 'bad': 2, 'reputation': 2, 'visit': 1, 'especially': 1, 'someone': 7, 'el': 2, 'free': 6, 'risk': 1, 'help': 1, 'fumbled': 1, 'knapsack': 3, 'revolver': 7, 'coughing': 1, 'sternly': 4, 'tapped': 2, 'windowframe': 1, 'whip': 2, 'hey': 3, 'within': 1, 'cried': 1, 'granny': 6, 'let': 8, 'me': 32, 'warm': 3, 'hoarse': 2, 'bark': 1, 'black': 8, 'rolled': 1, 'like': 15, 'ball': 1, 'under': 9, 'foot': 6, 'another': 9, 'white': 10, 'onethere': 1, 'must': 11, 'dozen': 2, 'them': 12, 'looked': 19, 'see': 6, 'biggest': 1, 'swung': 1, 'lashed': 1, 'longlegged': 1, 'puppy': 1, 'turned': 4, 'sharp': 2, 'muzzle': 1, 'upwards': 1, 'set': 6, 'shrill': 1, 'piercing': 1, 'howl': 1, 'while': 8, 'tapping': 3, 'hoarfrost': 1, 'tree': 1, 'near': 5, 'glowed': 1, 'muffled': 1, 'female': 1, 'figure': 2, 'appeared': 2, 'lantern': 2, 'hand': 11, 'said': 40, 'i': 56, 'driving': 3, 'my': 28, 'such': 3, 'weather': 3, 'god': 6, 'preserve': 1, 'u': 6, 'dont': 5, 'afraid': 3, 'your': 6, 'own': 2, 'people': 6, 'didnt': 1, 'invite': 1, 'stranger': 2, 'grimly': 1, 'you': 35, 'knocking': 2, 'locked': 2, 'yard': 6, 'stopped': 2, 'step': 2, 'bid': 1, 'labourer': 3, 'take': 8, 'out': 34, 'indeed': 1, 'she': 45, 'putting': 1, 'light': 5, 'fell': 3, 'face': 7, 'saw': 6, 'eyebrow': 1, 'recognized': 2, 'now': 10, 'went': 24, 'drunk': 4, 'asleep': 7, 'gone': 4, 'since': 2, 'morning': 4, 'holiday': 2, 'fastened': 1, 'shed': 2, 'neigh': 1, 'distinguished': 1, 'darkness': 3, 'felt': 2, 'cossack': 1, 'saddle': 3, 'so': 11, 'else': 1, 'besides': 1, 'woman': 7, 'greater': 1, 'security': 1, 'unsaddled': 1, 'took': 8, 'both': 5, 'room': 16, 'large': 1, 'hot': 1, 'smelt': 1, 'freshly': 2, 'washed': 2, 'floor': 11, 'short': 1, 'lean': 1, 'peasant': 16, 'forty': 1, 'fair': 2, 'beard': 2, 'wearing': 2, 'dark': 7, 'blue': 5, 'shirt': 2, 'sitting': 5, 'table': 8, 'holy': 3, 'image': 3, 'kalashnikov': 26, 'arrant': 1, 'scoundrel': 1, 'horsestealer': 1 ...

# %% [markdown]
# ## 5. Calculating IDF

# %%
import ast
f = open("index.txt", "r")
data = f.read()
index = ast.literal_eval(data)
f.close()

f = open("dictionary.txt", "r")
data = f.read()
dictionary = ast.literal_eval(data)
f.close()



for word in dictionary.keys():
    count = 0
    for doc in index.keys():
        if index[doc].get(word) != None:
            count = count + 1
#    calculate idf and store it in 
#    dictionary[word][2] as idf for each term

# %% [markdown]
# ## 5. Positional Index

# %%
f = open("positionalIndex.txt", "w")
    
with open('positionalIndex.txt', 'w') as the_file:
    f.write('{')
    for word in dictionary:
#         print('"{}":"{}"\n'.format(word, dictionary[word] ))
        f.write("'{}':{},\n".format(word, dictionary[word] ))
    f.write('}')

    f.close()

# %% [markdown]
# ## 6. Reading Inverted Index

# %%
import ast
f = open("invertedIndex.txt", "r")
data = f.read()
invertedIndex = ast.literal_eval(data)
print(invertedIndex['beard'])
# Out:
# [1, 2, 4, 6, 11, 20, 21, 23, 25, 26, 31, 34, 40, 44]

# %% [markdown]
# ## 7. Reading Positional Index

# %%
import ast
f = open("positionalIndex.txt", "r")
data = f.read()
positionalIndex = ast.literal_eval(data)
print(positionalIndex['beard'])
# Out:
# {1: {737, 1978}, 2: {2074, 4442, 591}, 4: {752}, 6: {152}, 11: {205, 719}, 20: {36, 511}, 21: {134}, 23: {2145, 2882, 3641, 4382, 1151}, 25: {5758, 559}, 26: {972}, 31: {12}, 34: {490, 822}, 40: {674}, 44: {909}}

# %% [markdown]
# ## 8. Normal Query

# %%
def normalQuery(query):

    currentIndex = 0
    resultDocs = set()
    universalSet = set(range(1,51))
    error = False
#     For First Word
    if query[currentIndex] == "not":
        resultForWord = set(invertedIndex[ps.stem(query[currentIndex + 1])]) 
#       taking Not
        resultDocs = resultDocs.union(universalSet - resultForWord)
        currentIndex += 2
    else:
        resultDocs = resultDocs.union(set(invertedIndex[ps.stem(query[currentIndex])]))
        currentIndex += 1
              
#   For Second Word

    if len(query) > currentIndex:
    
#     Does the second word have AND or OR
        if query[currentIndex] == "and":
        
#           Is the second word with a not ?
            if query[currentIndex + 1] == "not":
                resultForWord = set(invertedIndex[ps.stem(query[currentIndex + 2])])      
#               taking Not
                takingNot = universalSet - resultForWord
#               Intersection Due to 'AND'
                resultDocs = resultDocs.intersection(takingNot)
                currentIndex += 3
            else:
                resultDocs = resultDocs.intersection(set(invertedIndex[ps.stem(query[currentIndex + 1])]))
                currentIndex += 2

                
        elif query[currentIndex] == "or":
            if query[currentIndex] == "not":
                resultForWord = set(invertedIndex[ps.stem(query[currentIndex + 2])])
                
#               ----------------taking Not
                resultDocs = resultDocs.union(universalSet - resultForWord)

                currentIndex += 3
            else:
                resultDocs = resultDocs.union(set(invertedIndex[ps.stem(query[currentIndex + 1])]))
                currentIndex += 2
        else: 
            print("Invalid Query, kindly mention any of (AND, OR, NOT) operators between each word")
            error = True;
            
#   For Third Word

    if len(query) > currentIndex and not error:
        
#     Does the third word have AND or OR
        if query[currentIndex] == "and":
        
#           Is the third word with a not ?
            if query[currentIndex + 1] == "not":
                resultForWord = set(invertedIndex[ps.stem(query[currentIndex + 2])])      
#               taking Not
                takingNot = universalSet - resultForWord
    
#               Intersection Due to 'AND'
                resultDocs = resultDocs.intersection(takingNot)
                currentIndex += 3
            else:
#               union due to OR
                resultDocs = resultDocs.intersection(set(invertedIndex[ps.stem(query[currentIndex + 1])]))
                currentIndex += 2

                
        elif query[currentIndex] == "or":
            if query[currentIndex] == "not":
                resultForWord = set(invertedIndex[ps.stem(query[currentIndex + 2])])      
#               taking Not
                resultDocs = resultDocs.union(universalSet - resultForWord)

                currentIndex += 3
            else:
#               union due to OR
                resultDocs = resultDocs.union(set(invertedIndex[ps.stem(query[currentIndex + 1])]))
                currentIndex += 2
        else: 
            print("Invalid Query, kindly mention any of (AND, OR, NOT) operators between each word")
            error = True
    
    if(not error):
        print(resultDocs)
        return resultDocs

# %% [markdown]
# ## 9. Proximity Query

# %%
def proximityQuery(word1, word2, k):
    k = int(k)
    qualified = set()
    firstWordFiles = positionalIndex[ps.stem(word1)]
    secondWordFiles = positionalIndex[ps.stem(word2)]
    
#     Finding Sets of each dictionary keys
    word1Set = set(firstWordFiles)
    word2Set = set(secondWordFiles)
    
#     Finding common keys
    result = word1Set.intersection(word2Set)

#     Finding compliment of keys with their respective sets to find uncommon keys 
    word1Set = word1Set - result
    word2Set = word2Set - result
    
#     Removing the uncommon keys from word Files
    for uslessfile in word1Set:
        firstWordFiles.pop(uslessfile)

    for uslessfile in word2Set:
        secondWordFiles.pop(uslessfile)
    
#     Finding K distance files
    for file in secondWordFiles:
        for locationOfWord in secondWordFiles[file]:
            result = set(range(locationOfWord - k - 1,locationOfWord + k + 1)).intersection(firstWordFiles[file])
            if(len(result)):
                qualified.add(file)

    print(qualified)
    return qualified

proximityQuery('smiling', 'face', 3)
# Out:
# {25, 11, 6, 22}
# {6, 11, 22, 25}

# %% [markdown]
# ## 9. Handling a Query

# %%
# query = "filling room /1".lower().split()
import sys
# print(query)
def handle_query():
#     query = inputBox.get("1.0","end-1c")
    query = input()
    query = query.lower().split()
    if query[len(query) - 1][0] == '/':
        # It is a proximity Query
        result = proximityQuery(query[0], query[1], query[2][1])
#         result_box.delete(0.0, 'end')
#         result_box.insert('end', result)
        print(result)
    else:
        # It is a normal Query
        result = normalQuery(query)
#         result_box.delete(0.0, 'end')
#         result_box.insert('end', result)
        print(result)

# %%
handle_query()
# Out:
# lover bullet /3
# {15}
# {15}

# %% [markdown]
# ## 10. Main Function GUI

# %%
root = tk.Tk()
root.geometry("600x400")
root.title('Boolean Retreival Model')


tk.Label(root, text="Boolean Retreival Model", font=("Roboto", 20)).pack(pady=(5, 10))


tk.Label(root, text="Search...", font=("Roboto", 12)).pack(pady=(10, 2))


inputBox = tk.Entry(root, font=("Roboto", 12), width=45)

inputBox.pack()


submitButton = tk.Button(root, text="SUBMIT", width=40, command=handle_query).pack()


tk.Label(root, text="Result Documents", font=("Roboto", 12)).pack(pady=(10, 2))

root.bind('<Return>', handle_query)

    # resultBox
result_box = tk.Text(root, width=50, height=5, font=("Roboto", 12), wrap='word')

result_box.pack(pady=(0, 10))


root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/maxplanko89/anaconda3/lib/python3.8/tkinter/__init__.py", line 1883, in __call__
#     return self.func(*args)
#   File "<ipython-input-13-b8f82868c207>", line 5, in handle_query
#     query = inputBox.get("1.0","end-1c")
# TypeError: get() takes 1 positional argument but 3 were given

# %% [markdown]
# # Modules

# %% [markdown]
# ## Finding All Characters used before translating

# %%
allchars = set()    
for word in dictionary:
        for letter in word:
            allchars.add(letter)
print(allchars)
# Out:
# {'9', '0', '—', 'i', 'u', 'q', '2', 'e', 'ª', 'z', 'y', '”', '8', 'd', 'v', 'o', 'm', 'f', 'b', '¨', '7', '1', 'a', '’', 'l', 'w', '§', 'j', '“', 'x', 'g', '©', 'p', '6', '3', 'r', 'c', 't', 'ã', '5', '´', '¯', '‘', 'h', '4', 's', 'k', 'n'}

# %% [markdown]
# ## String Processing

# %%
import sys
import string 


    #   Read a Line and work on it and repeat
line = "my long string's big 9 sentance anti-social different 1str@ing!"
        
    #   End of line Found

line = line.lower()
line = line.translate(str.maketrans('','',string.punctuation))
line = line.translate(str.maketrans('','','1234567890'))
line = line.translate(str.maketrans('','','“”‘’"—'))

# words = word_tokenize(line)

print("Line: ", line)
# print("Words: ", words)
# Out:
# Line:  my long strings big  sentance antisocial my different string

# %% [markdown]
# ## Stemming

# %%
# import nltk
# nltk.download()
# importing modules
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
words = word_tokenize("my long string's big sentance that-make different 1str@ing!")
ps = PorterStemmer()

for w in words:
    print(w, " \t\t:\t", ps.stem(w))
# Out:
# my  		:	 my
# long  		:	 long
# string  		:	 string
# 's  		:	 's
# big  		:	 big
# sentance  		:	 sentanc
# that-make  		:	 that-mak
# different  		:	 differ
# 1str  		:	 1str
# @  		:	 @
# ing  		:	 ing
# !  		:	 !

# %% [markdown]
# ## StopWords

# %%
import sys
import string
from nltk.stem import PorterStemmer

f = open("stopwords.txt", "r")
stopwords = []
while(1):
    line = f.readline().strip()
    if(not line):
        break
    stopwords.append(line)
f.close()
for psword in stopwords:
    print(psword, ps.stem(psword))
# Out:
# a a
# is is
# the the
# of of
# all all
# and and
# to to
# can can
# be be
# as as
# once onc
# for for
# at at
# am am
# are are
# has ha
# have have
# had had
# up up
# his hi
# her her
# in in
# on on
# no no
# we we
# do do

# %% [markdown]
# ## Removing StopWords

# %%
f = open("stopwords.txt", "r")
stopWords = f.read().split()
for stopword in stopWords:
    dictionary.pop(ps.stem(stopword))
f.close()
print("Dictionary Length: ", len(dictionary))

# %% [markdown]
# ## Moving to Dictionary

# %%
import sys
import string
from nltk.stem import PorterStemmer
 
ps = PorterStemmer()

def readFile(file):
#     f = open(f"./ShortStories/{file}.txt", encoding="utf8")
    f=open('./ShortStories/{}.txt'.format(file), encoding='utf-8')
    
    #   Read and Lower Case 
    line = f.read().lower()    
        
    #   Removing Punctuations
    line = line.translate(str.maketrans('','',string.punctuation))

    # We have identified all unique characters and numbers and removed all others but alphabets       
    # '9', '0', '—', 'i', 'u', 'q', '2', 'e', 'ª', 'z', 'y', '”', '8', 'd', 'v', 'o', 'm', 'f', 'b', '¨', '7', '1', 'a', '’', 'l', 'w', '§', 'j', '“', 'x', 'g', '©', 'p', '6', '3', 'r', 'c', 't', 'ã', '5', '´', '¯', '‘', 'h', '4', 's', 'k', 'n
    line = line.translate(str.maketrans('','','1234567890©§“”‘’"´¨¯—ªã'))
        
    for word in line.split():
        word = ps.stem(word)
        if word in dictionary.keys():
            dictionary[word].add(file)
        else:
            dictionary[word] = {file}


    f.close()
    return

dictionary = {}

# Run for Each File
for x in range(1,51):
    readFile(x)
    
    
    
print("Dictionary Length: ", len(dictionary))
# print(dictionary)
# Out:
# Dictionary Length:  6789

# %%
print({range(234,237)})
# Out:
# {range(234, 237)}
